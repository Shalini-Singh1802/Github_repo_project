# %% [markdown]
# <a href="https://colab.research.google.com/github/Shalini-Singh1802/Github_repo_project/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#from sklearn.preprocessing import StandardScalar
from sklearn.decomposition import PCA

# %%
np.random.seed(42)
x =np.random.rand(100,6)*10

# %%
pca = PCA (n_components=2)

# %%
x_pca = pca.fit_transform(x)

# %%
print("original size:",x.shape)
print("original size:",x_pca.shape)
# Out:
# original size: (100, 6)
# original size: (100, 2)
